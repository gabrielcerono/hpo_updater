# %%
import os 
from bioportal_client import BioPortalClient
import pandas as pd

# %%
def get_bioportal_mappings(from_ontology, to_ontology):
    api_key = "225a7f07-744e-41fc-b8e8-7c3d9b11a100"
    client = BioPortalClient(api_key)
    return client.get_mappings(from_ontology, to_ontology)

# %% [markdown]
# # Getting the Mappings

# %% [markdown]
# ### HPO to MESH

# %%
hpo_mesh = get_bioportal_mappings('HP', 'MESH')

# %%
len(hpo_mesh)
# Out:
# 923

# %%
hpo_mesh
# Out:
# {'http://purl.bioontology.org/ontology/MESH/D007007': 'http://purl.obolibrary.org/obo/HP_0000966',
#  'http://purl.bioontology.org/ontology/MESH/D065707': 'http://purl.obolibrary.org/obo/HP_0010636',
#  'http://purl.bioontology.org/ontology/MESH/D012162': 'http://purl.obolibrary.org/obo/HP_0000546',
#  'http://purl.bioontology.org/ontology/MESH/D006628': 'http://purl.obolibrary.org/obo/HP_0001007',
#  'http://purl.bioontology.org/ontology/MESH/D009845': 'http://purl.obolibrary.org/obo/HP_0000798',
#  'http://purl.bioontology.org/ontology/MESH/D004716': 'http://purl.obolibrary.org/obo/HP_0025636',
#  'http://purl.bioontology.org/ontology/MESH/D006327': 'http://purl.obolibrary.org/obo/HP_0012722',
#  'http://purl.bioontology.org/ontology/MESH/D014973': 'http://purl.obolibrary.org/obo/HP_0000991',
#  'http://purl.bioontology.org/ontology/MESH/D018908': 'http://purl.obolibrary.org/obo/HP_0001324',
#  'http://purl.bioontology.org/ontology/MESH/D020069': 'http://purl.obolibrary.org/obo/HP_0030834',
#  'http://purl.bioontology.org/ontology/MESH/D010985': 'http://purl.obolibrary.org/obo/HP_0002691',
#  'http://purl.bioontology.org/ontology/MESH/D018325': 'http://purl.obolibrary.org/obo/HP_0010797',
#  'http://purl.bioontology.org/ontology/MESH/D009400': 'http://purl.obolibrary.org/obo/HP_0009741',
#  'http://purl.bioontology.org/ontology/MESH/D003555': 'http://purl.obolibrary.org/obo/HP_0003131',
#  'http://purl.bioontology.org/ontology/MESH/D010518': 'http://purl.obolibrary.org/obo/HP_0000704',
#  'http://purl.bioontology.org/ontology/MESH/D053609': 'http://purl.obolibrary.org/obo/HP_0001254',
#  'http://purl.bioontology.org/ontology/MESH/D006941': 'http://purl.obolibrary.org/obo/HP_0100963',
#  'http://purl.bioontology.org/ontology/MESH/D012804': 'http://purl.obolibrary.org/obo/HP_0011704',
#  'http://purl.bioontology.org/ontology/MESH/D015746': 'http://purl.obolibrary.org/obo/HP_0002027',
#  'http://purl.bioontology.org/ontology/MESH/D004774': 'http://purl.obolibrary.org/obo/HP_0000621',
#  'http://purl.bioontology.org/ontology/MESH/D020047': 'http://purl.obolibrary.org/obo/HP_0100822',
#  'http://purl.bioontology.org/ontology/MESH/D004933': 'http://purl.obolibrary.org/obo/HP_0002032',
#  'http://purl.bioontology.org/ontology/MESH/D002386': 'http://purl.obolibrary.org/obo/HP_0000518',
#  'http://purl.bioontology.org/ontology/MESH/D015878': 'http://purl.obolibrary.org/obo/HP_0011499',
#  'http://purl.bioontology.org/ontology/MESH/D020335': 'http://purl.obolibrary.org/obo/HP_0002385',
#  'http://purl.bioontology.org/ontology/MESH/D011317': 'http://purl.obolibrary.org/obo/HP_0200023',
#  'http://purl.bioontology.org/ontology/MESH/D001164': 'http://purl.obolibrary.org/obo/HP_0004947',
#  'http://purl.bioontology.org/ontology/MESH/D009325': 'http://purl.obolibrary.org/obo/HP_0002018',
#  'http://purl.bioontology.org/ontology/MESH/D001988': 'http://purl.obolibrary.org/obo/HP_0011950',
#  'http://purl.bioontology.org/ontology/MESH/D018237': 'http://purl.obolibrary.org/obo/HP_0100620',
#  'http://purl.bioontology.org/ontology/MESH/D059020': 'http://purl.obolibrary.org/obo/HP_0031589',
#  'http://purl.bioontology.org/ontology/MESH/D018281': 'http://purl.obolibrary.org/obo/HP_0030153',
#  'http://purl.bioontology.org/ontology/MESH/C538377': 'http://purl.obolibrary.org/obo/HP_0007570',
#  'http://purl.bioontology.org/ontology/MESH/D009259': 'http://purl.obolibrary.org/obo/HP_0012170',
#  'http://purl.bioontology.org/ontology/MESH/D053565': 'http://purl.obolibrary.org/obo/HP_0002150',
#  'http://purl.bioontology.org/ontology/MESH/D006073': 'http://purl.obolibrary.org/obo/HP_0001997',
#  'http://purl.bioontology.org/ontology/MESH/D011141': 'http://purl.obolibrary.org/obo/HP_0000103',
#  'http://purl.bioontology.org/ontology/MESH/D006985': 'http://purl.obolibrary.org/obo/HP_0002883',
#  'http://purl.bioontology.org/ontology/MESH/D005901': 'http://purl.obolibrary.org/obo/HP_0000501',
#  'http://purl.bioontology.org/ontology/MESH/D014826': 'http://purl.obolibrary.org/obo/HP_0001605',
#  'http://purl.bioontology.org/ontology/MESH/D055091': 'http://purl.obolibrary.org/obo/HP_0002780',
#  'http://purl.bioontology.org/ontology/MESH/D012848': 'http://purl.obolibrary.org/obo/HP_0012723',
#  'http://purl.bioontology.org/ontology/MESH/D004410': 'http://purl.obolibrary.org/obo/HP_0010522',
#  'http://purl.bioontology.org/ontology/MESH/D022124': 'http://purl.obolibrary.org/obo/HP_0001987',
#  'http://purl.bioontology.org/ontology/MESH/D013923': 'http://purl.obolibrary.org/obo/HP_0001907',
#  'http://purl.bioontology.org/ontology/MESH/D003310': 'http://purl.obolibrary.org/obo/HP_0010774',
#  'http://purl.bioontology.org/ontology/MESH/D007640': 'http://purl.obolibrary.org/obo/HP_0000563',
#  'http://purl.bioontology.org/ontology/MESH/D001007': 'http://purl.obolibrary.org/obo/HP_0000739',
#  'http://purl.bioontology.org/ontology/MESH/D000080041': 'http://purl.obolibrary.org/obo/HP_0011540',
#  'http://purl.bioontology.org/ontology/MESH/D001919': 'http://purl.obolibrary.org/obo/HP_0001662',
#  'http://purl.bioontology.org/ontology/MESH/D012883': 'http://purl.obolibrary.org/obo/HP_0200042',
#  'http://purl.bioontology.org/ontology/MESH/D005096': 'http://purl.obolibrary.org/obo/HP_0100777',
#  'http://purl.bioontology.org/ontology/MESH/D007662': 'http://purl.obolibrary.org/obo/HP_0001946',
#  'http://purl.bioontology.org/ontology/MESH/D012279': 'http://purl.obolibrary.org/obo/HP_0002748',
#  'http://purl.bioontology.org/ontology/MESH/D014202': 'http://purl.obolibrary.org/obo/HP_0001337',
#  'http://purl.bioontology.org/ontology/MESH/C565029': 'http://purl.obolibrary.org/obo/HP_0002219',
#  'http://purl.bioontology.org/ontology/MESH/D001998': 'http://purl.obolibrary.org/obo/HP_0010960',
#  'http://purl.bioontology.org/ontology/MESH/D008342': 'http://purl.obolibrary.org/obo/HP_0005321',
#  'http://purl.bioontology.org/ontology/MESH/D007738': 'http://purl.obolibrary.org/obo/HP_0002808',
#  'http://purl.bioontology.org/ontology/MESH/D020235': 'http://purl.obolibrary.org/obo/HP_0010521',
#  'http://purl.bioontology.org/ontology/MESH/D005334': 'http://purl.obolibrary.org/obo/HP_0001945',
#  'http://purl.bioontology.org/ontology/MESH/C562400': 'http://purl.obolibrary.org/obo/HP_0007406',
#  'http://purl.bioontology.org/ontology/MESH/C563255': 'http://purl.obolibrary.org/obo/HP_0030961',
#  'http://purl.bioontology.org/ontology/MESH/D006484': 'http://purl.obolibrary.org/obo/HP_0032551',
#  'http://purl.bioontology.org/ontology/MESH/D002305': 'http://purl.obolibrary.org/obo/HP_0033415',
#  'http://purl.bioontology.org/ontology/MESH/D006973': 'http://purl.obolibrary.org/obo/HP_0000822',
#  'http://purl.bioontology.org/ontology/MESH/D008545': 'http://purl.obolibrary.org/obo/HP_0002861',
#  'http://purl.bioontology.org/ontology/MESH/D006547': 'http://purl.obolibrary.org/obo/HP_0100790',
#  'http://purl.bioontology.org/ontology/MESH/D009222': 'http://purl.obolibrary.org/obo/HP_0002486',
#  'http://purl.bioontology.org/ontology/MESH/D007637': 'http://purl.obolibrary.org/obo/HP_0001096',
#  'http://purl.bioontology.org/ontology/MESH/D003449': 'http://purl.obolibrary.org/obo/HP_0100778',
#  'http://purl.bioontology.org/ontology/MESH/D012792': 'http://purl.obolibrary.org/obo/HP_0100962',
#  'http://purl.bioontology.org/ontology/MESH/D001281': 'http://purl.obolibrary.org/obo/HP_0005110',
#  'http://purl.bioontology.org/ontology/MESH/D006111': 'http://purl.obolibrary.org/obo/HP_0100647',
#  'http://purl.bioontology.org/ontology/MESH/D007938': 'http://purl.obolibrary.org/obo/HP_0001909',
#  'http://purl.bioontology.org/ontology/MESH/D002972': 'http://purl.obolibrary.org/obo/HP_0000175',
#  'http://purl.bioontology.org/ontology/MESH/D002637': 'http://purl.obolibrary.org/obo/HP_0100749',
#  'http://purl.bioontology.org/ontology/MESH/D006396': 'http://purl.obolibrary.org/obo/HP_0002248',
#  'http://purl.bioontology.org/ontology/MESH/C566826': 'http://purl.obolibrary.org/obo/HP_0002697',
#  'http://purl.bioontology.org/ontology/MESH/D056807': 'http://purl.obolibrary.org/obo/HP_0025630',
#  'http://purl.bioontology.org/ontology/MESH/D014525': 'http://purl.obolibrary.org/obo/HP_0012227',
#  'http://purl.bioontology.org/ontology/MESH/D004483': 'http://purl.obolibrary.org/obo/HP_0000656',
#  'http://purl.bioontology.org/ontology/MESH/D001437': 'http://purl.obolibrary.org/obo/HP_0012461',
#  'http://purl.bioontology.org/ontology/MESH/D007246': 'http://purl.obolibrary.org/obo/HP_0000789',
#  'http://purl.bioontology.org/ontology/MESH/D001014': 'http://purl.obolibrary.org/obo/HP_0004942',
#  'http://purl.bioontology.org/ontology/MESH/D000787': 'http://purl.obolibrary.org/obo/HP_0001681',
#  'http://purl.bioontology.org/ontology/MESH/D013169': 'http://purl.obolibrary.org/obo/HP_0003304',
#  'http://purl.bioontology.org/ontology/MESH/D000686': 'http://purl.obolibrary.org/obo/HP_0011034',
#  'http://purl.bioontology.org/ontology/MESH/D007647': 'http://purl.obolibrary.org/obo/HP_0001343',
#  'http://purl.bioontology.org/ontology/MESH/D002647': 'http://purl.obolibrary.org/obo/HP_0009710',
#  'http://purl.bioontology.org/ontology/MESH/D014657': 'http://purl.obolibrary.org/obo/HP_0002633',
#  'http://purl.bioontology.org/ontology/MESH/D010033': 'http://purl.obolibrary.org/obo/HP_0000388',
#  'http://purl.bioontology.org/ontology/MESH/D004414': 'http://purl.obolibrary.org/obo/HP_0030016',
#  'http://purl.bioontology.org/ontology/MESH/D000567': 'http://purl.obolibrary.org/obo/HP_0000705',
#  'http://purl.bioontology.org/ontology/MESH/D019547': 'http://purl.obolibrary.org/obo/HP_0030833',
#  'http://purl.bioontology.org/ontology/MESH/D000855': 'http://purl.obolibrary.org/obo/HP_0002039',
#  'http://purl.bioontology.org/ontology/MESH/D004461': 'http://purl.obolibrary.org/obo/HP_0100601',
#  'http://purl.bioontology.org/ontology/MESH/C562733': 'http://purl.obolibrary.org/obo/HP_0030642',
#  'http://purl.bioontology.org/ontology/MESH/D013009': 'http://purl.obolibrary.org/obo/HP_0025236',
#  'http://purl.bioontology.org/ontology/MESH/C536185': 'http://purl.obolibrary.org/obo/HP_0009918',
#  'http://purl.bioontology.org/ontology/MESH/D008417': 'http://purl.obolibrary.org/obo/HP_0000265',
#  'http://purl.bioontology.org/ontology/MESH/D053099': 'http://purl.obolibrary.org/obo/HP_0002157',
#  'http://purl.bioontology.org/ontology/MESH/D060905': 'http://purl.obolibrary.org/obo/HP_0002812',
#  'http://purl.bioontology.org/ontology/MESH/D002916': 'http://purl.obolibrary.org/obo/HP_0010310',
#  'http://purl.bioontology.org/ontology/MESH/D016728': 'http://purl.obolibrary.org/obo/HP_0100716',
#  'http://purl.bioontology.org/ontology/MESH/D002051': 'http://purl.obolibrary.org/obo/HP_0030080',
#  'http://purl.bioontology.org/ontology/MESH/D008708': 'http://purl.obolibrary.org/obo/HP_0012119',
#  'http://purl.bioontology.org/ontology/MESH/D055154': 'http://purl.obolibrary.org/obo/HP_0001618',
#  'http://purl.bioontology.org/ontology/MESH/D010024': 'http://purl.obolibrary.org/obo/HP_0000939',
#  'http://purl.bioontology.org/ontology/MESH/D006469': 'http://purl.obolibrary.org/obo/HP_0002105',
#  'http://purl.bioontology.org/ontology/MESH/D011625': 'http://purl.obolibrary.org/obo/HP_0001059',
#  'http://purl.bioontology.org/ontology/MESH/D045262': 'http://purl.obolibrary.org/obo/HP_0001923',
#  'http://purl.bioontology.org/ontology/MESH/D010309': 'http://purl.obolibrary.org/obo/HP_0011850',
#  'http://purl.bioontology.org/ontology/MESH/D012163': 'http://purl.obolibrary.org/obo/HP_0000541',
#  'http://purl.bioontology.org/ontology/MESH/D006732': 'http://purl.obolibrary.org/obo/HP_0002277',
#  'http://purl.bioontology.org/ontology/MESH/D012166': 'http://purl.obolibrary.org/obo/HP_0000573',
#  'http://purl.bioontology.org/ontology/MESH/D012652': 'http://purl.obolibrary.org/obo/HP_0000742',
#  'http://purl.bioontology.org/ontology/MESH/D001259': 'http://purl.obolibrary.org/obo/HP_0001251',
#  'http://purl.bioontology.org/ontology/MESH/D002547': 'http://purl.obolibrary.org/obo/HP_0100021',
#  'http://purl.bioontology.org/ontology/MESH/D007412': 'http://purl.obolibrary.org/obo/HP_0100819',
#  'http://purl.bioontology.org/ontology/MESH/D020139': 'http://purl.obolibrary.org/obo/HP_0001543',
#  'http://purl.bioontology.org/ontology/MESH/D001024': 'http://purl.obolibrary.org/obo/HP_0001650',
#  'http://purl.bioontology.org/ontology/MESH/D000073496': 'http://purl.obolibrary.org/obo/HP_0033675',
#  'http://purl.bioontology.org/ontology/MESH/D001251': 'http://purl.obolibrary.org/obo/HP_0000483',
#  'http://purl.bioontology.org/ontology/MESH/D010040': 'http://purl.obolibrary.org/obo/HP_0000362',
#  'http://purl.bioontology.org/ontology/MESH/D004421': 'http://purl.obolibrary.org/obo/HP_0001332',
#  'http://purl.bioontology.org/ontology/MESH/D013226': 'http://purl.obolibrary.org/obo/HP_0002133',
#  'http://purl.bioontology.org/ontology/MESH/D000087122': 'http://purl.obolibrary.org/obo/HP_0100754',
#  'http://purl.bioontology.org/ontology/MESH/D057091': 'http://purl.obolibrary.org/obo/HP_0031405',
#  'http://purl.bioontology.org/ontology/MESH/D010188': 'http://purl.obolibrary.org/obo/HP_0001738',
#  'http://purl.bioontology.org/ontology/MESH/D003409': 'http://purl.obolibrary.org/obo/HP_0000851',
#  'http://purl.bioontology.org/ontology/MESH/D031222': 'http://purl.obolibrary.org/obo/HP_0002999',
#  'http://purl.bioontology.org/ontology/MESH/D012559': 'http://purl.obolibrary.org/obo/HP_0100753',
#  'http://purl.bioontology.org/ontology/MESH/D012600': 'http://purl.obolibrary.org/obo/HP_0002650',
#  'http://purl.bioontology.org/ontology/MESH/D004844': 'http://purl.obolibrary.org/obo/HP_0000421',
#  'http://purl.bioontology.org/ontology/MESH/D006429': 'http://purl.obolibrary.org/obo/HP_0002301',
#  'http://purl.bioontology.org/ontology/MESH/D004696': 'http://purl.obolibrary.org/obo/HP_0100584',
#  'http://purl.bioontology.org/ontology/MESH/D006391': 'http://purl.obolibrary.org/obo/HP_0001028',
#  'http://purl.bioontology.org/ontology/MESH/D000799': 'http://purl.obolibrary.org/obo/HP_0100665',
#  'http://purl.bioontology.org/ontology/MESH/D054880': 'http://purl.obolibrary.org/obo/HP_0012068',
#  'http://purl.bioontology.org/ontology/MESH/D020412': 'http://purl.obolibrary.org/obo/HP_0001426',
#  'http://purl.bioontology.org/ontology/MESH/D002754': 'http://purl.obolibrary.org/obo/HP_0000453',
#  'http://purl.bioontology.org/ontology/MESH/D050497': 'http://purl.obolibrary.org/obo/HP_0003826',
#  'http://purl.bioontology.org/ontology/MESH/D006617': 'http://purl.obolibrary.org/obo/HP_0002827',
#  'http://purl.bioontology.org/ontology/MESH/D056650': 'http://purl.obolibrary.org/obo/HP_0030943',
#  'http://purl.bioontology.org/ontology/MESH/D016569': 'http://purl.obolibrary.org/obo/HP_0000581',
#  'http://purl.bioontology.org/ontology/MESH/D007040': 'http://purl.obolibrary.org/obo/HP_0002791',
#  'http://purl.bioontology.org/ontology/MESH/D003920': 'http://purl.obolibrary.org/obo/HP_0000819',
#  'http://purl.bioontology.org/ontology/MESH/D002817': 'http://purl.obolibrary.org/obo/HP_0010762',
#  'http://purl.bioontology.org/ontology/MESH/D010842': 'http://purl.obolibrary.org/obo/HP_0011856',
#  'http://purl.bioontology.org/ontology/MESH/D000794': 'http://purl.obolibrary.org/obo/HP_0001014',
#  'http://purl.bioontology.org/ontology/MESH/D010018': 'http://purl.obolibrary.org/obo/HP_0002749',
#  'http://purl.bioontology.org/ontology/MESH/C562684': 'http://purl.obolibrary.org/obo/HP_0012556',
#  'http://purl.bioontology.org/ontology/MESH/D045823': 'http://purl.obolibrary.org/obo/HP_0002595',
#  'http://purl.bioontology.org/ontology/MESH/D014549': 'http://purl.obolibrary.org/obo/HP_0000020',
#  'http://purl.bioontology.org/ontology/MESH/D015551': 'http://purl.obolibrary.org/obo/HP_0002960',
#  'http://purl.bioontology.org/ontology/MESH/D013163': 'http://purl.obolibrary.org/obo/HP_0001744',
#  'http://purl.bioontology.org/ontology/MESH/D010263': 'http://purl.obolibrary.org/obo/HP_0100588',
#  'http://purl.bioontology.org/ontology/MESH/D006529': 'http://purl.obolibrary.org/obo/HP_0002240',
#  'http://purl.bioontology.org/ontology/MESH/D006304': 'http://purl.obolibrary.org/obo/HP_0032319',
#  'http://purl.bioontology.org/ontology/MESH/D000138': 'http://purl.obolibrary.org/obo/HP_0001941',
#  'http://purl.bioontology.org/ontology/MESH/C531747': 'http://purl.obolibrary.org/obo/HP_0007188',
#  'http://purl.bioontology.org/ontology/MESH/D014596': 'http://purl.obolibrary.org/obo/HP_0000139',
#  'http://purl.bioontology.org/ontology/MESH/D005928': 'http://purl.obolibrary.org/obo/HP_0000206',
#  'http://purl.bioontology.org/ontology/MESH/D011654': 'http://purl.obolibrary.org/obo/HP_0100598',
#  'http://purl.bioontology.org/ontology/MESH/D058186': 'http://purl.obolibrary.org/obo/HP_0001919',
#  'http://purl.bioontology.org/ontology/MESH/D019584': 'http://purl.obolibrary.org/obo/HP_0031217',
#  'http://purl.bioontology.org/ontology/MESH/D001167': 'http://purl.obolibrary.org/obo/HP_0012089',
#  'http://purl.bioontology.org/ontology/MESH/D010192': 'http://purl.obolibrary.org/obo/HP_0005206',
#  'http://purl.bioontology.org/ontology/MESH/D001994': 'http://purl.obolibrary.org/obo/HP_0100730',
# ...
#  'http://purl.bioontology.org/ontology/MESH/D013966': 'http://purl.obolibrary.org/obo/HP_0100646',
#  'http://purl.bioontology.org/ontology/MESH/D000051': 'http://purl.obolibrary.org/obo/HP_0100792',
#  'http://purl.bioontology.org/ontology/MESH/D011704': 'http://purl.obolibrary.org/obo/HP_0012330',
#  'http://purl.bioontology.org/ontology/MESH/D013342': 'http://purl.obolibrary.org/obo/HP_0025268',
#  'http://purl.bioontology.org/ontology/MESH/D014646': 'http://purl.obolibrary.org/obo/HP_0012871',
#  'http://purl.bioontology.org/ontology/MESH/D010022': 'http://purl.obolibrary.org/obo/HP_0011002',
#  'http://purl.bioontology.org/ontology/MESH/D002485': 'http://purl.obolibrary.org/obo/HP_0012328',
#  'http://purl.bioontology.org/ontology/MESH/D012208': 'http://purl.obolibrary.org/obo/HP_0002859',
#  'http://purl.bioontology.org/ontology/MESH/D002971': 'http://purl.obolibrary.org/obo/HP_0410030',
#  'http://purl.bioontology.org/ontology/MESH/D006332': 'http://purl.obolibrary.org/obo/HP_0001640',
#  'http://purl.bioontology.org/ontology/MESH/D008415': 'http://purl.obolibrary.org/obo/HP_0100495',
#  'http://purl.bioontology.org/ontology/MESH/D003970': 'http://purl.obolibrary.org/obo/HP_0000699',
#  'http://purl.bioontology.org/ontology/MESH/D000405': 'http://purl.obolibrary.org/obo/HP_0012672',
#  'http://purl.bioontology.org/ontology/MESH/C536330': 'http://purl.obolibrary.org/obo/HP_0006557',
#  'http://purl.bioontology.org/ontology/MESH/C535315': 'http://purl.obolibrary.org/obo/HP_0003607',
#  'http://purl.bioontology.org/ontology/MESH/D010996': 'http://purl.obolibrary.org/obo/HP_0002202',
#  'http://purl.bioontology.org/ontology/MESH/D015861': 'http://purl.obolibrary.org/obo/HP_0030666',
#  'http://purl.bioontology.org/ontology/MESH/D001247': 'http://purl.obolibrary.org/obo/HP_0025406',
#  'http://purl.bioontology.org/ontology/MESH/D005921': 'http://purl.obolibrary.org/obo/HP_0000099',
#  'http://purl.bioontology.org/ontology/MESH/D010235': 'http://purl.obolibrary.org/obo/HP_0002668',
#  'http://purl.bioontology.org/ontology/MESH/D004941': 'http://purl.obolibrary.org/obo/HP_0100633',
#  'http://purl.bioontology.org/ontology/MESH/C562398': 'http://purl.obolibrary.org/obo/HP_0003067',
#  'http://purl.bioontology.org/ontology/MESH/D000073872': 'http://purl.obolibrary.org/obo/HP_0010775',
#  'http://purl.bioontology.org/ontology/MESH/D000740': 'http://purl.obolibrary.org/obo/HP_0001903',
#  'http://purl.bioontology.org/ontology/MESH/D003914': 'http://purl.obolibrary.org/obo/HP_0001651',
#  'http://purl.bioontology.org/ontology/MESH/D058529': 'http://purl.obolibrary.org/obo/HP_0001195',
#  'http://purl.bioontology.org/ontology/MESH/D008181': 'http://purl.obolibrary.org/obo/HP_0033726',
#  'http://purl.bioontology.org/ontology/MESH/D002613': 'http://purl.obolibrary.org/obo/HP_0100825',
#  'http://purl.bioontology.org/ontology/MESH/D016055': 'http://purl.obolibrary.org/obo/HP_0000016',
#  'http://purl.bioontology.org/ontology/MESH/D000086722': 'http://purl.obolibrary.org/obo/HP_0031417',
#  'http://purl.bioontology.org/ontology/MESH/D000377': 'http://purl.obolibrary.org/obo/HP_0010524',
#  'http://purl.bioontology.org/ontology/MESH/D044483': 'http://purl.obolibrary.org/obo/HP_0200008',
#  'http://purl.bioontology.org/ontology/MESH/D006222': 'http://purl.obolibrary.org/obo/HP_0010566',
#  'http://purl.bioontology.org/ontology/MESH/D008305': 'http://purl.obolibrary.org/obo/HP_0002047',
#  'http://purl.bioontology.org/ontology/MESH/D053589': 'http://purl.obolibrary.org/obo/HP_0012498',
#  'http://purl.bioontology.org/ontology/MESH/D002037': 'http://purl.obolibrary.org/obo/HP_0011710',
#  'http://purl.bioontology.org/ontology/MESH/C538457': 'http://purl.obolibrary.org/obo/HP_0033495',
#  'http://purl.bioontology.org/ontology/MESH/D010501': 'http://purl.obolibrary.org/obo/HP_0012784',
#  'http://purl.bioontology.org/ontology/MESH/C537963': 'http://purl.obolibrary.org/obo/HP_0004490',
#  'http://purl.bioontology.org/ontology/MESH/D000072281': 'http://purl.obolibrary.org/obo/HP_0002716',
#  'http://purl.bioontology.org/ontology/MESH/D004823': 'http://purl.obolibrary.org/obo/HP_0000031',
#  'http://purl.bioontology.org/ontology/MESH/D002276': 'http://purl.obolibrary.org/obo/HP_0100570',
#  'http://purl.bioontology.org/ontology/MESH/D024182': 'http://purl.obolibrary.org/obo/HP_0032382',
#  'http://purl.bioontology.org/ontology/MESH/D000550': 'http://purl.obolibrary.org/obo/HP_0000646',
#  'http://purl.bioontology.org/ontology/MESH/C566478': 'http://purl.obolibrary.org/obo/HP_0012215',
#  'http://purl.bioontology.org/ontology/MESH/D000437': 'http://purl.obolibrary.org/obo/HP_0030955',
#  'http://purl.bioontology.org/ontology/MESH/D015875': 'http://purl.obolibrary.org/obo/HP_0009916',
#  'http://purl.bioontology.org/ontology/MESH/D059407': 'http://purl.obolibrary.org/obo/HP_0031830',
#  'http://purl.bioontology.org/ontology/MESH/D018149': 'http://purl.obolibrary.org/obo/HP_0001952',
#  'http://purl.bioontology.org/ontology/MESH/D004381': 'http://purl.obolibrary.org/obo/HP_0002588',
#  'http://purl.bioontology.org/ontology/MESH/D002012': 'http://purl.obolibrary.org/obo/HP_0003763',
#  'http://purl.bioontology.org/ontology/MESH/D004806': 'http://purl.obolibrary.org/obo/HP_0002888',
#  'http://purl.bioontology.org/ontology/MESH/D016470': 'http://purl.obolibrary.org/obo/HP_0031864',
#  'http://purl.bioontology.org/ontology/MESH/D055008': 'http://purl.obolibrary.org/obo/HP_0033375',
#  'http://purl.bioontology.org/ontology/MESH/D006399': 'http://purl.obolibrary.org/obo/HP_0031923',
#  'http://purl.bioontology.org/ontology/MESH/D007019': 'http://purl.obolibrary.org/obo/HP_0003075',
#  'http://purl.bioontology.org/ontology/MESH/D002198': 'http://purl.obolibrary.org/obo/HP_0025017',
#  'http://purl.bioontology.org/ontology/MESH/D006828': 'http://purl.obolibrary.org/obo/HP_0032192',
#  'http://purl.bioontology.org/ontology/MESH/D009503': 'http://purl.obolibrary.org/obo/HP_0001875',
#  'http://purl.bioontology.org/ontology/MESH/D001471': 'http://purl.obolibrary.org/obo/HP_0100580',
#  'http://purl.bioontology.org/ontology/MESH/D050197': 'http://purl.obolibrary.org/obo/HP_0002621',
#  'http://purl.bioontology.org/ontology/MESH/D000086582': 'http://purl.obolibrary.org/obo/HP_0000458',
#  'http://purl.bioontology.org/ontology/MESH/D007906': 'http://purl.obolibrary.org/obo/HP_0001132',
#  'http://purl.bioontology.org/ontology/MESH/D000757': 'http://purl.obolibrary.org/obo/HP_0002323',
#  'http://purl.bioontology.org/ontology/MESH/C562408': 'http://purl.obolibrary.org/obo/HP_0002974',
#  'http://purl.bioontology.org/ontology/MESH/D012585': 'http://purl.obolibrary.org/obo/HP_0011868',
#  'http://purl.bioontology.org/ontology/MESH/D010019': 'http://purl.obolibrary.org/obo/HP_0002754',
#  'http://purl.bioontology.org/ontology/MESH/D003965': 'http://purl.obolibrary.org/obo/HP_0009110',
#  'http://purl.bioontology.org/ontology/MESH/D020325': 'http://purl.obolibrary.org/obo/HP_0002077',
#  'http://purl.bioontology.org/ontology/MESH/D054082': 'http://purl.obolibrary.org/obo/HP_0001339',
#  'http://purl.bioontology.org/ontology/MESH/D012516': 'http://purl.obolibrary.org/obo/HP_0002669',
#  'http://purl.bioontology.org/ontology/MESH/D009397': 'http://purl.obolibrary.org/obo/HP_0000121',
#  'http://purl.bioontology.org/ontology/MESH/D013161': 'http://purl.obolibrary.org/obo/HP_0012223',
#  'http://purl.bioontology.org/ontology/MESH/D020795': 'http://purl.obolibrary.org/obo/HP_0000613',
#  'http://purl.bioontology.org/ontology/MESH/D010264': 'http://purl.obolibrary.org/obo/HP_0010550',
#  'http://purl.bioontology.org/ontology/MESH/D009205': 'http://purl.obolibrary.org/obo/HP_0012819',
#  'http://purl.bioontology.org/ontology/MESH/D011655': 'http://purl.obolibrary.org/obo/HP_0002204',
#  'http://purl.bioontology.org/ontology/MESH/D005487': 'http://purl.obolibrary.org/obo/HP_0003651',
#  'http://purl.bioontology.org/ontology/MESH/D014597': 'http://purl.obolibrary.org/obo/HP_0100718',
#  'http://purl.bioontology.org/ontology/MESH/D004387': 'http://purl.obolibrary.org/obo/HP_0005679',
#  'http://purl.bioontology.org/ontology/MESH/D016883': 'http://purl.obolibrary.org/obo/HP_0001953',
#  'http://purl.bioontology.org/ontology/MESH/D013117': 'http://purl.obolibrary.org/obo/HP_0002176',
#  'http://purl.bioontology.org/ontology/MESH/D057180': 'http://purl.obolibrary.org/obo/HP_0002145',
#  'http://purl.bioontology.org/ontology/MESH/D001019': 'http://purl.obolibrary.org/obo/HP_0031649',
#  'http://purl.bioontology.org/ontology/MESH/D003811': 'http://purl.obolibrary.org/obo/HP_0000703',
#  'http://purl.bioontology.org/ontology/MESH/D001264': 'http://purl.obolibrary.org/obo/HP_0002305',
#  'http://purl.bioontology.org/ontology/MESH/D058568': 'http://purl.obolibrary.org/obo/HP_0031181',
#  'http://purl.bioontology.org/ontology/MESH/D013575': 'http://purl.obolibrary.org/obo/HP_0001279',
#  'http://purl.bioontology.org/ontology/MESH/D001079': 'http://purl.obolibrary.org/obo/HP_0040192',
#  'http://purl.bioontology.org/ontology/MESH/D012005': 'http://purl.obolibrary.org/obo/HP_0002035',
#  'http://purl.bioontology.org/ontology/MESH/D002100': 'http://purl.obolibrary.org/obo/HP_0004326',
#  'http://purl.bioontology.org/ontology/MESH/D000070603': 'http://purl.obolibrary.org/obo/HP_0003279',
#  'http://purl.bioontology.org/ontology/MESH/D009798': 'http://purl.obolibrary.org/obo/HP_0007906',
#  'http://purl.bioontology.org/ontology/MESH/D007787': 'http://purl.obolibrary.org/obo/HP_0004789',
#  'http://purl.bioontology.org/ontology/MESH/D006261': 'http://purl.obolibrary.org/obo/HP_0002315',
#  'http://purl.bioontology.org/ontology/MESH/D009447': 'http://purl.obolibrary.org/obo/HP_0003006',
#  'http://purl.bioontology.org/ontology/MESH/D005756': 'http://purl.obolibrary.org/obo/HP_0005263',
#  'http://purl.bioontology.org/ontology/MESH/D004760': 'http://purl.obolibrary.org/obo/HP_0004387',
#  'http://purl.bioontology.org/ontology/MESH/D006505': 'http://purl.obolibrary.org/obo/HP_0012115',
#  'http://purl.bioontology.org/ontology/MESH/D006988': 'http://purl.obolibrary.org/obo/HP_0011886',
#  'http://purl.bioontology.org/ontology/MESH/D057092': 'http://purl.obolibrary.org/obo/HP_0031609',
#  'http://purl.bioontology.org/ontology/MESH/D015831': 'http://purl.obolibrary.org/obo/HP_0030431',
#  'http://purl.bioontology.org/ontology/MESH/D008200': 'http://purl.obolibrary.org/obo/HP_0031842',
#  'http://purl.bioontology.org/ontology/MESH/D020162': 'http://purl.obolibrary.org/obo/HP_0500153'}

# %%
hpo_mesh_df = pd.DataFrame.from_dict(hpo_mesh, orient='index', columns = ['HPO'])
hpo_mesh_df.reset_index(inplace = True)

# %%
hpo_mesh_df['HPO']=hpo_mesh_df['HPO'].apply(lambda row: row.split('_')[-1])
hpo_mesh_df['MESH']=hpo_mesh_df['index'].apply(lambda row: row.split('/')[-1])
hpo_mesh_df.drop(columns = 'index', inplace = True)

# %%
hpo_mesh_df.head(3)
# Out:
#        HPO     MESH
# 0  0000966  D007007
# 1  0010636  D065707
# 2  0000546  D012162

# %% [markdown]
# ### DOID to OMIM

# %%
doid_omim = get_bioportal_mappings("DOID", "OMIM")

# %%
do_omim_df = pd.DataFrame.from_dict(doid_omim, orient='index', columns = ['OMIM'])
do_omim_df.reset_index(inplace = True)

# %%
do_omim_df['DOID']=do_omim_df['index'].apply(lambda row: row.split('_')[-1])
do_omim_df['OMIM']=do_omim_df['OMIM'].apply(lambda row: row.split('/')[-1])
do_omim_df.drop(columns = 'index', inplace = True)

# %%
do_omim_df.head(3)
# Out:
#          OMIM     DOID
# 0  MTHU039740     8986
# 1      617904  0080291
# 2  MTHU013769     1572

# %% [markdown]
# ### DOID to ORPHA

# %%
doid_orpha = get_bioportal_mappings('DOID', 'ORDO')

# %%
do_orpha_df = pd.DataFrame.from_dict(doid_orpha, orient='index', columns = ['ORPHA'])
do_orpha_df.reset_index(inplace = True)

# %%
do_orpha_df['DOID']=do_orpha_df['index'].apply(lambda row: row.split('_')[-1])
do_orpha_df['ORPHA']=do_orpha_df['ORPHA'].apply(lambda row: row.split('_')[-1])
do_orpha_df.drop(columns = 'index', inplace = True)

# %%
do_orpha_df.head(3)
# Out:
#     ORPHA     DOID
# 0  364559     1934
# 1   90652  0111784
# 2     178     3302

# %% [markdown]
# ## HPO to DO mappings

# %%
hpo_do = get_bioportal_mappings("HP", "DOID")
# For some reason it is returning a mixed mapping,
# containing SYMP, HPO AND DO TO HPO.
# I clean the mapping by doing a partial string match

# %%
hpo_do_df = pd.DataFrame.from_dict(hpo_do, orient='index', columns = ['HPO'])
hpo_do_df.reset_index(inplace = True)

# %%
hpo_do_df = hpo_do_df.loc[hpo_do_df['index'].str.contains('DOID', na = False)]

# %%
hpo_do_df['DOID']=hpo_do_df['index'].apply(lambda row: row.split('_')[-1])
hpo_do_df['HPO']=hpo_do_df['HPO'].apply(lambda row: row.split('_')[-1])

# %%
hpo_do_df.drop(columns = 'index', inplace = True)

# %%
hpo_do_df
# Out:
#           HPO  DOID
# 0     0030050  8986
# 2     0002343  1572
# 4     0010762  3302
# 6     0100324   419
# 8     0011950  2942
# ...       ...   ...
# 1454  0004810  1342
# 1455  0012474   807
# 1456  0001004  4977
# 1458  0012197  3892
# 1461  0007705  1237
#
# [842 rows x 2 columns]

# %% [markdown]
# ## Mappings parsed
# \
# \
# #### HPO to Mesh  =  hpo_mesh_df
# \
# #### OMIM to DO   =  do_omim_df
# \
# #### ORPHA to DO  =  do_orpha_df
# \
# #### HPO to DO = hpo_do_df

# %% [markdown]
# # Parsing the Edges

# %%
hpo_annot = pd.read_csv('hpo_anot.txt', delimiter = "\t", skiprows = 2, header = None)

# %%
header_key = ["HPO_ID", "HPO_LABEL", "gen_id", "gen_name", "info_from_source", "source", "disease_id"]

# %%
hpo_annot.columns = header_key
hpo_annot.drop(columns = 'info_from_source', inplace = True)

# %%
hpo_annot
# Out:
#              HPO_ID                                       HPO_LABEL  gen_id  \
# 0        HP:0000002                      Abnormality of body height    6138
# 1        HP:0000002                      Abnormality of body height    7227
# 2        HP:0000002                      Abnormality of body height    3835
# 3        HP:0000002                      Abnormality of body height    4001
# 4        HP:0000002                      Abnormality of body height     545
# ...             ...                                             ...     ...
# 1021766  HP:0032754                     Focal aware sensory seizure   64780
# 1021767  HP:0032754                     Focal aware sensory seizure    5649
# 1021768  HP:0032759  Focal sensory seizure with vestibular features    9211
# 1021769  HP:0032759  Focal sensory seizure with vestibular features   64780
# 1021770  HP:0032759  Focal sensory seizure with vestibular features    5649
#
#         gen_name     source   disease_id
# 0          RPL15  orphadata    ORPHA:124
# 1          TRPS1   mim2gene  OMIM:190351
# 2          KIF22   mim2gene  OMIM:603546
# 3          LMNB1  orphadata   ORPHA:2514
# 4            ATR  orphadata    ORPHA:808
# ...          ...        ...          ...
# 1021766   MICAL1   mim2gene  OMIM:600512
# 1021767     RELN   mim2gene  OMIM:600512
# 1021768     LGI1   mim2gene  OMIM:600512
# 1021769   MICAL1   mim2gene  OMIM:600512
# 1021770     RELN   mim2gene  OMIM:600512
#
# [1021771 rows x 6 columns]

# %% [markdown]
# ### The messy part

# %% [markdown]
# We don't have HPO on SPOKE, but we have MESH. We can use mappings from HPO to MESH, and just use the MESH nodes to build edges.
#
# Edges from HPO can be connected to DOID (Diseases) but only through OMIM-DOID mappings or ORPHA-DOID mappings.

# %% [markdown]
# ### HPO / MESH ---> (edge) --> to OMIM/DOID

# %%
hpo_edge_omim = hpo_annot.loc[hpo_annot['disease_id'].str.contains('OMIM', na = False)]

# %%
hpo_edge_omim['OMIM'] = hpo_edge_omim['disease_id'].apply(lambda row : row.split(':')[-1])
# Out:
# <ipython-input-35-f7ff9ce908ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hpo_edge_omim['OMIM'] = hpo_edge_omim['disease_id'].apply(lambda row : row.split(':')[-1])

# %%
hpo_edge_omim['HPO'] = hpo_edge_omim['HPO_ID'].apply(lambda row : row.split(':')[-1])
# Out:
# <ipython-input-36-9a682d19f69d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hpo_edge_omim['HPO'] = hpo_edge_omim['HPO_ID'].apply(lambda row : row.split(':')[-1])

# %%
hpo_mesh_edge_to_omim = hpo_edge_omim.merge(hpo_mesh_df, how = 'inner', on = 'HPO')

# %%
hpo_mesh_edge_to_omim['OMIM'] = hpo_mesh_edge_to_omim['disease_id'].apply(lambda row : row.split(':')[-1])

# %%
hpo_mesh_edge_to_omim_do = hpo_mesh_edge_to_omim.merge(do_omim_df, how = 'inner', on = 'OMIM')

# %% [markdown]
# #### HPO / MESH ---> (edge) --> to OMIM/DOID result

# %%
hpo_mesh_edge_to_omim_do.drop(columns=['gen_name', 'gen_id', 'HPO_ID', 'source', 'disease_id'], inplace = True)

# %%
hpo_mesh_edge_to_omim_do
# Out:
#                    HPO_LABEL    OMIM      HPO     MESH   DOID
# 0       Bladder diverticulum  194050  0000015  C562406   1928
# 1       Bladder diverticulum  194050  0000015  C562406   1928
# 2      Vesicoureteral reflux  194050  0000076  D014718   1928
# 3      Vesicoureteral reflux  194050  0000076  D014718   1928
# 4        Renal insufficiency  194050  0000083  D051437   1928
# ...                      ...     ...      ...      ...    ...
# 10966          Pilomatrixoma  132600  0030434  D018296   5374
# 10967   Fundus albipunctatus  136880  0030642  C562733  11105
# 10968   Fundus albipunctatus  136880  0030642  C562733  11105
# 10969   Fundus albipunctatus  136880  0030642  C562733  11105
# 10970   Fundus albipunctatus  136880  0030642  C562733  11105
#
# [10971 rows x 5 columns]

# %%
hpo_mesh_edge_to_omim_do.drop_duplicates(inplace=True)

# %%
hpo_mesh_edge_to_omim_do.to_csv('hpo_mesh_edge_to_omim_do.csv')

# %% [markdown]
# ### HPO / DOID (mapped)---> (edge) --> to OMIM/DOID

# %%
hpo_do_edge_omim = hpo_edge_omim.merge(hpo_do_df, how = 'inner', on = 'HPO')

# %%
hpo_do_edge_omim
# Out:
#            HPO_ID                     HPO_LABEL  gen_id  gen_name    source  \
# 0      HP:0000011            Neurogenic bladder    2697      GJA1  mim2gene
# 1      HP:0000011            Neurogenic bladder    2019       EN1  mim2gene
# 2      HP:0000011            Neurogenic bladder    6885    MAP3K7  mim2gene
# 3      HP:0000011            Neurogenic bladder   10466      COG5  mim2gene
# 4      HP:0000011            Neurogenic bladder   55823     VPS11  mim2gene
# ...           ...                           ...     ...       ...       ...
# 24195  HP:0032409  Subcortical band heterotopia    5048  PAFAH1B1  mim2gene
# 24196  HP:0032409  Subcortical band heterotopia   79633      FAT4  mim2gene
# 24197  HP:0032409  Subcortical band heterotopia  387119    CEP85L  mim2gene
# 24198  HP:0032564                       Ileitis    5970      RELA  mim2gene
# 24199  HP:0032564                       Ileitis   22900     CARD8  mim2gene
#
#         disease_id    OMIM      HPO     DOID
# 0      OMIM:164200  164200  0000011    12143
# 1      OMIM:619218  619218  0000011    12143
# 2      OMIM:617137  617137  0000011    12143
# 3      OMIM:613612  613612  0000011    12143
# 4      OMIM:616683  616683  0000011    12143
# ...            ...     ...      ...      ...
# 24195  OMIM:607432  607432  0032409  0111169
# 24196  OMIM:615546  615546  0032409  0111169
# 24197  OMIM:618873  618873  0032409  0111169
# 24198  OMIM:618287  618287  0032564  0060189
# 24199  OMIM:619079  619079  0032564  0060189
#
# [24200 rows x 9 columns]

# %%
hpo_do_edge_omim.rename(columns = {'DOID' : 'DOID_MAP'}, inplace = True)

# %%
hpo_do_edge_omim['OMIM'] = hpo_do_edge_omim['disease_id'].apply(lambda row : row.split(':')[-1])

# %%
hpo_do_edge_omim_do = hpo_do_edge_omim.merge(do_omim_df, how = 'inner', on = 'OMIM')

# %%
hpo_do_edge_omim_do.rename(columns = {'DOID' : 'EDGES_TO_DOID'}, inplace = True)

# %% [markdown]
# #### This DOID --> (EDGE) --> DOID, might seem weird, but a disease like "aortic aneurysm" presents in syndromes like "Marfan Syndrome".

# %%
hpo_do_edge_omim_do
# Out:
#           HPO_ID            HPO_LABEL  gen_id gen_name    source   disease_id  \
# 0     HP:0000011   Neurogenic bladder    2697     GJA1  mim2gene  OMIM:164200
# 1     HP:0000175         Cleft palate    2697     GJA1  mim2gene  OMIM:164200
# 2     HP:0000252         Microcephaly    2697     GJA1  mim2gene  OMIM:164200
# 3     HP:0410030            Cleft lip    2697     GJA1  mim2gene  OMIM:164200
# 4     HP:0000501             Glaucoma    2697     GJA1  mim2gene  OMIM:164200
# ...          ...                  ...     ...      ...       ...          ...
# 8526  HP:0030078  Lung adenocarcinoma    1548   CYP2A6  mim2gene  OMIM:211980
# 8527  HP:0030078  Lung adenocarcinoma    1956     EGFR  mim2gene  OMIM:211980
# 8528  HP:0030078  Lung adenocarcinoma    5519  PPP2R1B  mim2gene  OMIM:211980
# 8529  HP:0030078  Lung adenocarcinoma     673     BRAF  mim2gene  OMIM:211980
# 8530  HP:0030434        Pilomatrixoma    1499   CTNNB1  mim2gene  OMIM:132600
#
#         OMIM      HPO DOID_MAP EDGES_TO_DOID
# 0     164200  0000011    12143       0060291
# 1     164200  0000175      674       0060291
# 2     164200  0000252    10907       0060291
# 3     164200  0410030     9296       0060291
# 4     164200  0000501     1686       0060291
# ...      ...      ...      ...           ...
# 8526  211980  0030078     3910          1324
# 8527  211980  0030078     3910          1324
# 8528  211980  0030078     3910          1324
# 8529  211980  0030078     3910          1324
# 8530  132600  0030434     5374          5374
#
# [8531 rows x 10 columns]

# %%
hpo_do_edge_omim_do.drop(columns = ['gen_name', 'gen_id', 'HPO_ID', 'source', 'disease_id'], inplace = True)

# %%
hpo_do_edge_omim_do.drop_duplicates(inplace=True)

# %%
hpo_do_edge_omim_do.to_csv('hpo_do_edge_to_omim_do.csv')

# %% [markdown]
# ### HPO / MESH --> (edge) --> ORPHA/DOID

# %%
hpo_edge_orpha = hpo_annot.loc[hpo_annot['disease_id'].str.contains('ORPHA', na = False)]

# %%
hpo_edge_orpha
# Out:
#              HPO_ID                   HPO_LABEL  gen_id gen_name     source  \
# 0        HP:0000002  Abnormality of body height    6138    RPL15  orphadata
# 3        HP:0000002  Abnormality of body height    4001    LMNB1  orphadata
# 4        HP:0000002  Abnormality of body height     545      ATR  orphadata
# 5        HP:0000002  Abnormality of body height    1499   CTNNB1  orphadata
# 8        HP:0000002  Abnormality of body height   50937     CDON  orphadata
# ...             ...                         ...     ...      ...        ...
# 1021745  HP:0032679     Focal non-motor seizure   81704    DOCK8  orphadata
# 1021748  HP:0032679     Focal non-motor seizure   10369   CACNG2  orphadata
# 1021751  HP:0032680     Focal cognitive seizure    8131    NPRL3  orphadata
# 1021752  HP:0032680     Focal cognitive seizure    9681   DEPDC5  orphadata
# 1021755  HP:0032680     Focal cognitive seizure   10641    NPRL2  orphadata
#
#            disease_id
# 0           ORPHA:124
# 3          ORPHA:2514
# 4           ORPHA:808
# 5         ORPHA:54595
# 8        ORPHA:280200
# ...               ...
# 1021745  ORPHA:178469
# 1021748  ORPHA:178469
# 1021751   ORPHA:98820
# 1021752   ORPHA:98820
# 1021755   ORPHA:98820
#
# [589736 rows x 6 columns]

# %%
hpo_edge_orpha['ORPHA'] = hpo_edge_orpha['disease_id'].apply(lambda row : row.split(':')[-1])
# Out:
# <ipython-input-56-d896751785de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hpo_edge_orpha['ORPHA'] = hpo_edge_orpha['disease_id'].apply(lambda row : row.split(':')[-1])

# %%
hpo_edge_orpha['HPO'] = hpo_edge_orpha['HPO_ID'].apply(lambda row : row.split(':')[-1])
# Out:
# <ipython-input-57-fad8ee888c47>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hpo_edge_orpha['HPO'] = hpo_edge_orpha['HPO_ID'].apply(lambda row : row.split(':')[-1])

# %%
hpo_mesh_edge_to_orpha = hpo_edge_orpha.merge(hpo_mesh_df, how = 'inner', on = 'HPO')

# %%
hpo_mesh_edge_to_orpha_do = hpo_mesh_edge_to_orpha.merge(do_orpha_df, how = 'inner', on = 'ORPHA')

# %%
hpo_mesh_edge_to_orpha_do.drop(columns = ['gen_name', 'gen_id', 'HPO_ID', 'source', 'disease_id'], inplace = True)

# %%
hpo_mesh_edge_to_orpha_do
# Out:
#                     HPO_LABEL   ORPHA      HPO     MESH     DOID
# 0        Bladder diverticulum     198  0000015  C562406  0111272
# 1            Pectus carinatum     198  0000768  D066166  0111272
# 2                Osteoporosis     198  0000939  D010024  0111272
# 3                    Jaundice     198  0000952  D007565  0111272
# 4               Brachydactyly     198  0001156  D059327  0111272
# ...                       ...     ...      ...      ...      ...
# 20130    Hypercholesterolemia   79506  0003124  D006937  0111368
# 20131                   Nevus     840  0003764  D009506     5445
# 20132         Epidermal nevus     840  0010816  C580062     5445
# 20133  Vascular calcification  289601  0004934  D061205  0111582
# 20134         Corneal opacity    1490  0007957  D003318  0111620
#
# [20135 rows x 5 columns]

# %%
hpo_mesh_edge_to_orpha_do.drop_duplicates(inplace=True)

# %%
hpo_mesh_edge_to_orpha_do.to_csv('hpo_mesh_edge_to_orpha_do.csv')

# %% [markdown]
# ### HPO / DOID (mapped)---> (edge) --> to ORPHA/DOID

# %%
hpo_edge_orpha
# Out:
#              HPO_ID                   HPO_LABEL  gen_id gen_name     source  \
# 0        HP:0000002  Abnormality of body height    6138    RPL15  orphadata
# 3        HP:0000002  Abnormality of body height    4001    LMNB1  orphadata
# 4        HP:0000002  Abnormality of body height     545      ATR  orphadata
# 5        HP:0000002  Abnormality of body height    1499   CTNNB1  orphadata
# 8        HP:0000002  Abnormality of body height   50937     CDON  orphadata
# ...             ...                         ...     ...      ...        ...
# 1021745  HP:0032679     Focal non-motor seizure   81704    DOCK8  orphadata
# 1021748  HP:0032679     Focal non-motor seizure   10369   CACNG2  orphadata
# 1021751  HP:0032680     Focal cognitive seizure    8131    NPRL3  orphadata
# 1021752  HP:0032680     Focal cognitive seizure    9681   DEPDC5  orphadata
# 1021755  HP:0032680     Focal cognitive seizure   10641    NPRL2  orphadata
#
#            disease_id   ORPHA      HPO
# 0           ORPHA:124     124  0000002
# 3          ORPHA:2514    2514  0000002
# 4           ORPHA:808     808  0000002
# 5         ORPHA:54595   54595  0000002
# 8        ORPHA:280200  280200  0000002
# ...               ...     ...      ...
# 1021745  ORPHA:178469  178469  0032679
# 1021748  ORPHA:178469  178469  0032679
# 1021751   ORPHA:98820   98820  0032680
# 1021752   ORPHA:98820   98820  0032680
# 1021755   ORPHA:98820   98820  0032680
#
# [589736 rows x 8 columns]

# %%
hpo_do_edge_orpha = hpo_edge_orpha.merge(hpo_do_df, how = 'inner', on = 'HPO')

# %%
hpo_do_edge_orpha.rename(columns = {'DOID' : 'DOID_MAP'}, inplace = True)

# %%
hpo_do_edge_orpha_do = hpo_do_edge_orpha.merge(do_orpha_df, how = 'inner', on = "ORPHA")

# %%
hpo_do_edge_orpha_do.rename(columns = {'DOID' : 'EDGES_TO_DOID'}, inplace = True)

# %%
hpo_do_edge_orpha_do.drop(columns = ['gen_name', 'gen_id', 'HPO_ID', 'source', 'disease_id'], inplace = True )

# %%
hpo_do_edge_orpha_do.drop_duplicates(inplace = True)

# %%
hpo_do_edge_orpha_do.to_csv('hpo_do_edge_orpha_do.csv')

# %% [markdown]
# ### HPO/SPOKE Matching

# %%
hpo_spoke_match = pd.read_csv("hpo_spoke_match.csv")

# %%
hpo_spoke_match.head(10)
# Out:
#        HPO_ID                   hpo     node_id                 node_name  \
# 0  HP:0003113         Hypochloremia    C0085680            Hypochloraemia
# 1  HP:0001067         Neurofibromas    C0027830              Neurofibroma
# 2  HP:0001067         Neurofibromas    DOID:962              neurofibroma
# 3  HP:0004409              Hyposmia    C2364082                  Hyposmia
# 4  HP:0001386        Joint swelling    C0152031            Joint swelling
# 5  HP:0032192     Hydatidiform mole    C0020217         Hydatidiform mole
# 6  HP:0032192     Hydatidiform mole    C0549315  Benign hydatidiform mole
# 7  HP:0000966          Hypohidrosis    C0020620              Hypohidrosis
# 8  HP:0000966          Hypohidrosis  DOID:11155              hypohidrosis
# 9  HP:0002671  Basal cell carcinoma    C0007117      Basal cell carcinoma
#
#     node_type  similarity
# 0  SideEffect          96
# 1  SideEffect          96
# 2     Disease          96
# 3  SideEffect         100
# 4  SideEffect         100
# 5  SideEffect         100
# 6  SideEffect          95
# 7  SideEffect         100
# 8     Disease         100
# 9  SideEffect         100

# %% [markdown]
# Similarity at 95 or below is hit or miss. It seems that 96 and above is the sweet spot

# %%
hpo_spoke_match = hpo_spoke_match.loc[hpo_spoke_match['similarity'] >= 96]

# %%
# Let's decrease complexity by using only disease

# %%
##hpo_spoke_match = hpo_spoke_match.loc[hpo_spoke_match['node_type'] == 'Disease']

# %% [markdown]
# Now let's merge it with all the anottations (Edges)

# %%
hpo_spoke_annot = hpo_spoke_match.merge(hpo_annot, how = 'inner', on='HPO_ID')

# %%
hpo_spoke_annot
# Out:
#             HPO_ID               hpo     node_id         node_name  \
# 0       HP:0003113     Hypochloremia    C0085680    Hypochloraemia
# 1       HP:0003113     Hypochloremia    C0085680    Hypochloraemia
# 2       HP:0003113     Hypochloremia    C0085680    Hypochloraemia
# 3       HP:0003113     Hypochloremia    C0085680    Hypochloraemia
# 4       HP:0003113     Hypochloremia    C0085680    Hypochloraemia
# ...            ...               ...         ...               ...
# 199291  HP:0001264  Spastic diplegia  DOID:10965  spastic diplegia
# 199292  HP:0001264  Spastic diplegia  DOID:10965  spastic diplegia
# 199293  HP:0001264  Spastic diplegia  DOID:10965  spastic diplegia
# 199294  HP:0001264  Spastic diplegia  DOID:10965  spastic diplegia
# 199295  HP:0001264  Spastic diplegia  DOID:10965  spastic diplegia
#
#          node_type  similarity         HPO_LABEL  gen_id  gen_name     source  \
# 0       SideEffect          96     Hypochloremia    1811   SLC26A3   mim2gene
# 1       SideEffect          96     Hypochloremia    7809      BSND  orphadata
# 2       SideEffect          96     Hypochloremia    3758     KCNJ1   mim2gene
# 3       SideEffect          96     Hypochloremia    6557   SLC12A1   mim2gene
# 4       SideEffect          96     Hypochloremia    1187    CLCNKA  orphadata
# ...            ...         ...               ...     ...       ...        ...
# 199291     Disease         100  Spastic diplegia    3028  HSD17B10  orphadata
# 199292     Disease         100  Spastic diplegia    8260     NAA10   mim2gene
# 199293     Disease         100  Spastic diplegia    1615     DARS1   mim2gene
# 199294     Disease         100  Spastic diplegia    8050      PDHX  orphadata
# 199295     Disease         100  Spastic diplegia    6657      SOX2   mim2gene
#
#           disease_id
# 0        OMIM:214700
# 1        ORPHA:89938
# 2        OMIM:241200
# 3        OMIM:601678
# 4        ORPHA:89938
# ...              ...
# 199291  ORPHA:391428
# 199292   OMIM:309800
# 199293   OMIM:615281
# 199294  ORPHA:255182
# 199295   OMIM:206900
#
# [199296 rows x 11 columns]

# %% [markdown]
# ### Let's merge on OMIM

# %%
hpo_spoke_annot.drop(columns = ['similarity', 'node_type', 'gen_id', 'gen_name', 'source'], inplace = True)

# %%
hpo_spoke_annot_omim = hpo_spoke_annot.loc[hpo_spoke_annot['disease_id'].str.contains('OMIM', na = False)]

# %%
hpo_spoke_annot_omim
# Out:
#             HPO_ID               hpo     node_id         node_name  \
# 0       HP:0003113     Hypochloremia    C0085680    Hypochloraemia
# 2       HP:0003113     Hypochloremia    C0085680    Hypochloraemia
# 3       HP:0003113     Hypochloremia    C0085680    Hypochloraemia
# 5       HP:0003113     Hypochloremia    C0085680    Hypochloraemia
# 6       HP:0003113     Hypochloremia    C0085680    Hypochloraemia
# ...            ...               ...         ...               ...
# 199289  HP:0001264  Spastic diplegia  DOID:10965  spastic diplegia
# 199290  HP:0001264  Spastic diplegia  DOID:10965  spastic diplegia
# 199292  HP:0001264  Spastic diplegia  DOID:10965  spastic diplegia
# 199293  HP:0001264  Spastic diplegia  DOID:10965  spastic diplegia
# 199295  HP:0001264  Spastic diplegia  DOID:10965  spastic diplegia
#
#                HPO_LABEL   disease_id
# 0          Hypochloremia  OMIM:214700
# 2          Hypochloremia  OMIM:241200
# 3          Hypochloremia  OMIM:601678
# 5          Hypochloremia  OMIM:602522
# 6          Hypochloremia  OMIM:613090
# ...                  ...          ...
# 199289  Spastic diplegia  OMIM:233400
# 199290  Spastic diplegia  OMIM:619065
# 199292  Spastic diplegia  OMIM:309800
# 199293  Spastic diplegia  OMIM:615281
# 199295  Spastic diplegia  OMIM:206900
#
# [76089 rows x 6 columns]

# %%
hpo_spoke_annot_omim['OMIM'] = hpo_spoke_annot_omim['disease_id'].apply(lambda x: x.split(':')[-1])
# Out:
# <ipython-input-82-00e3d73c1fa2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hpo_spoke_annot_omim['OMIM'] = hpo_spoke_annot_omim['disease_id'].apply(lambda x: x.split(':')[-1])

# %%
hpo_spoke_annot_omim = hpo_spoke_annot_omim.merge(do_omim_df, how = 'inner', on = 'OMIM')

# %%
hpo_spoke_annot_omim.to_csv('hpo_spoke_annot_omim')

# %%
hpo_spoke_annot_omim
# Out:
#            HPO_ID              hpo     node_id        node_name  \
# 0      HP:0001067    Neurofibromas    C0027830     Neurofibroma
# 1      HP:0001067    Neurofibromas    C0027830     Neurofibroma
# 2      HP:0001067    Neurofibromas    C0027830     Neurofibroma
# 3      HP:0001067    Neurofibromas    DOID:962     neurofibroma
# 4      HP:0001067    Neurofibromas    DOID:962     neurofibroma
# ...           ...              ...         ...              ...
# 25369  HP:0000028   Cryptorchidism  DOID:11383   cryptorchidism
# 25370  HP:0000787  Nephrolithiasis    C0392525  Nephrolithiasis
# 25371  HP:0000787  Nephrolithiasis    DOID:585  nephrolithiasis
# 25372  HP:0000252     Microcephaly    C0025958     Microcephaly
# 25373  HP:0000252     Microcephaly  DOID:10907     microcephaly
#
#              HPO_LABEL   disease_id    OMIM     DOID
# 0        Neurofibromas  OMIM:606764  606764     9253
# 1        Neurofibromas  OMIM:606764  606764     9253
# 2        Neurofibromas  OMIM:606764  606764     9253
# 3        Neurofibromas  OMIM:606764  606764     9253
# 4        Neurofibromas  OMIM:606764  606764     9253
# ...                ...          ...     ...      ...
# 25369   Cryptorchidism  OMIM:614279  614279  0111773
# 25370  Nephrolithiasis  OMIM:614723  614723  0060350
# 25371  Nephrolithiasis  OMIM:614723  614723  0060350
# 25372     Microcephaly  OMIM:211180  211180  0050684
# 25373     Microcephaly  OMIM:211180  211180  0050684
#
# [25374 rows x 8 columns]

# %%
hpo_spoke_annot_omim.duplicated().sum()
# Out:
# 3145

# %% [markdown]
# A lot of duplciated rows, we will drop them

# %%
hpo_spoke_annot_omim.drop_duplicates(inplace = True)

# %%
hpo_spoke_annot_omim
# Out:
#            HPO_ID                           hpo     node_id  \
# 0      HP:0001067                 Neurofibromas    C0027830
# 3      HP:0001067                 Neurofibromas    DOID:962
# 6      HP:0002015                     Dysphagia    C0011168
# 9      HP:0004796  Gastrointestinal obstruction    C0236124
# 12     HP:0005214        Intestinal obstruction    C0021843
# ...           ...                           ...         ...
# 25368  HP:0000028                Cryptorchidism  DOID:11383
# 25370  HP:0000787               Nephrolithiasis    C0392525
# 25371  HP:0000787               Nephrolithiasis    DOID:585
# 25372  HP:0000252                  Microcephaly    C0025958
# 25373  HP:0000252                  Microcephaly  DOID:10907
#
#                           node_name                     HPO_LABEL  \
# 0                      Neurofibroma                 Neurofibromas
# 3                      neurofibroma                 Neurofibromas
# 6                         Dysphagia                     Dysphagia
# 9      Gastrointestinal obstruction  Gastrointestinal obstruction
# 12           Intestinal obstruction        Intestinal obstruction
# ...                             ...                           ...
# 25368                cryptorchidism                Cryptorchidism
# 25370               Nephrolithiasis               Nephrolithiasis
# 25371               nephrolithiasis               Nephrolithiasis
# 25372                  Microcephaly                  Microcephaly
# 25373                  microcephaly                  Microcephaly
#
#         disease_id    OMIM     DOID
# 0      OMIM:606764  606764     9253
# 3      OMIM:606764  606764     9253
# 6      OMIM:606764  606764     9253
# 9      OMIM:606764  606764     9253
# 12     OMIM:606764  606764     9253
# ...            ...     ...      ...
# 25368  OMIM:614279  614279  0111773
# 25370  OMIM:614723  614723  0060350
# 25371  OMIM:614723  614723  0060350
# 25372  OMIM:211180  211180  0050684
# 25373  OMIM:211180  211180  0050684
#
# [22229 rows x 8 columns]

# %%
hpo_spoke_annot_omim.to_csv('hpo_spoke_annot_omim.csv')

# %% [markdown]
# ### Let's merge on ORPHA

# %%
hpo_spoke_annot_orpha = hpo_spoke_annot.loc[hpo_spoke_annot['disease_id'].str.contains('ORPHA', na = False)]

# %%
hpo_spoke_annot_orpha['ORPHA'] = hpo_spoke_annot_orpha['disease_id'].apply(lambda x: x.split(':')[-1])
# Out:
# <ipython-input-91-07e69580e0a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hpo_spoke_annot_orpha['ORPHA'] = hpo_spoke_annot_orpha['disease_id'].apply(lambda x: x.split(':')[-1])

# %%
hpo_spoke_annot_orpha = hpo_spoke_annot_orpha.merge(do_orpha_df, how = 'inner', on = 'ORPHA')

# %%
hpo_spoke_annot_orpha
# Out:
#            HPO_ID                   hpo       node_id             node_name  \
# 0      HP:0001067         Neurofibromas      C0027830          Neurofibroma
# 1      HP:0001067         Neurofibromas      C0027830          Neurofibroma
# 2      HP:0001067         Neurofibromas      C0027830          Neurofibroma
# 3      HP:0001067         Neurofibromas      C0027830          Neurofibroma
# 4      HP:0001067         Neurofibromas      C0027830          Neurofibroma
# ...           ...                   ...           ...                   ...
# 45172  HP:0002289  Alopecia universalis  DOID:0050634  alopecia universalis
# 45173  HP:0000453       Choanal atresia     DOID:9574       choanal atresia
# 45174  HP:0000453       Choanal atresia     DOID:9574       choanal atresia
# 45175  HP:0001561        Polyhydramnios      C0020224        Polyhydramnios
# 45176  HP:0001561        Polyhydramnios     DOID:8488        polyhydramnios
#
#                   HPO_LABEL  disease_id ORPHA     DOID
# 0             Neurofibromas  ORPHA:2495  2495     3565
# 1             Neurofibromas  ORPHA:2495  2495     3565
# 2             Neurofibromas  ORPHA:2495  2495     3565
# 3             Neurofibromas  ORPHA:2495  2495     3565
# 4             Neurofibromas  ORPHA:2495  2495     3565
# ...                     ...         ...   ...      ...
# 45172  Alopecia universalis   ORPHA:701   701  0050634
# 45173       Choanal atresia  ORPHA:1200  1200  0080695
# 45174       Choanal atresia  ORPHA:1200  1200  0080695
# 45175        Polyhydramnios  ORPHA:2300  2300    14671
# 45176        Polyhydramnios  ORPHA:2300  2300    14671
#
# [45177 rows x 8 columns]

# %%
hpo_spoke_annot_orpha.duplicated().sum()
# Out:
# 30992

# %%
hpo_spoke_annot_orpha.drop_duplicates(inplace = True)

# %%
hpo_spoke_annot_orpha
# Out:
#            HPO_ID                   hpo       node_id             node_name  \
# 0      HP:0001067         Neurofibromas      C0027830          Neurofibroma
# 12     HP:0001067         Neurofibromas      DOID:962          neurofibroma
# 24     HP:0002354     Memory impairment      C0233794     Memory impairment
# 36     HP:0001342   Cerebral hemorrhage      C2937358  Cerebral haemorrhage
# 48     HP:0000505     Visual impairment      C3665347     Visual impairment
# ...           ...                   ...           ...                   ...
# 45171  HP:0001596              Alopecia      DOID:987              alopecia
# 45172  HP:0002289  Alopecia universalis  DOID:0050634  alopecia universalis
# 45173  HP:0000453       Choanal atresia     DOID:9574       choanal atresia
# 45175  HP:0001561        Polyhydramnios      C0020224        Polyhydramnios
# 45176  HP:0001561        Polyhydramnios     DOID:8488        polyhydramnios
#
#                   HPO_LABEL  disease_id ORPHA     DOID
# 0             Neurofibromas  ORPHA:2495  2495     3565
# 12            Neurofibromas  ORPHA:2495  2495     3565
# 24        Memory impairment  ORPHA:2495  2495     3565
# 36      Cerebral hemorrhage  ORPHA:2495  2495     3565
# 48        Visual impairment  ORPHA:2495  2495     3565
# ...                     ...         ...   ...      ...
# 45171              Alopecia   ORPHA:701   701  0050634
# 45172  Alopecia universalis   ORPHA:701   701  0050634
# 45173       Choanal atresia  ORPHA:1200  1200  0080695
# 45175        Polyhydramnios  ORPHA:2300  2300    14671
# 45176        Polyhydramnios  ORPHA:2300  2300    14671
#
# [14185 rows x 8 columns]

# %%
hpo_spoke_annot_orpha.to_csv('hpo_spoke_annot_orpha.csv')

# %%
hpo_mesh_edge_to_orpha_do
# Out:
#                     HPO_LABEL   ORPHA      HPO     MESH     DOID
# 0        Bladder diverticulum     198  0000015  C562406  0111272
# 1            Pectus carinatum     198  0000768  D066166  0111272
# 2                Osteoporosis     198  0000939  D010024  0111272
# 3                    Jaundice     198  0000952  D007565  0111272
# 4               Brachydactyly     198  0001156  D059327  0111272
# ...                       ...     ...      ...      ...      ...
# 20129    Hypercholesterolemia   79506  0003124  D006937  0111368
# 20131                   Nevus     840  0003764  D009506     5445
# 20132         Epidermal nevus     840  0010816  C580062     5445
# 20133  Vascular calcification  289601  0004934  D061205  0111582
# 20134         Corneal opacity    1490  0007957  D003318  0111620
#
# [6412 rows x 5 columns]

# %%
hpo_mesh_edge_to_omim_do
# Out:
#                    HPO_LABEL    OMIM      HPO     MESH     DOID
# 0       Bladder diverticulum  194050  0000015  C562406     1928
# 2      Vesicoureteral reflux  194050  0000076  D014718     1928
# 4        Renal insufficiency  194050  0000083  D051437     1928
# 6           Nephrocalcinosis  194050  0000121  D009397     1928
# 8               Otitis media  194050  0000388  D010033     1928
# ...                      ...     ...      ...      ...      ...
# 10955               Erythema  617525  0010783  D004890  0080249
# 10956              Hepatitis  114550  0012115  D006505      684
# 10965             Hemothorax  262850  0012151  D006491  0060601
# 10966          Pilomatrixoma  132600  0030434  D018296     5374
# 10967   Fundus albipunctatus  136880  0030642  C562733    11105
#
# [9578 rows x 5 columns]

# %%
concatenado = pd.concat([hpo_mesh_edge_to_omim_do, hpo_mesh_edge_to_orpha_do], ignore_index= True)

# %%
concatenado.duplicated().sum()
# Out:
# 0
